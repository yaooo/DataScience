# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3>Student Information</h3> Please provide information about yourself. We will NOT grade this submissing w/o all the information<br>
# <b>Name</b>:<br>
# <b>NetID</b>:<br>
# <b>Recitation (01/02)</b>:<br>
# <b>Notes to Grader</b> (optional):<br>
# <br><br>
# <b>IMPORTANT</b>
# Your work will not be graded withour your initials below<br>
# I certify that this lab represents my own work and I have read the RU academic intergrity policies at<br>
# <a href="https://www.cs.rutgers.edu/academic-integrity/introduction">https://www.cs.rutgers.edu/academic-integrity/introduction </a><br>
# <b>Initials</b>:      (eg: DS for Deeptanshu Singh)
#
#
# <h3>Grader Notes</h3>
# <b>Your Grade<b>:<br>
# <b>Grader Initials</b>:<br>
# <b>Grader Comments</b> (optional):<br>
# </div>

# %% [markdown]
# ## CS 439 - Introduction to Data Science
# ### Spring 2019
#
# # Lab 3: Data Cleaning and Visualization
#
# ### Due Date: Sunday February 17, 2019 by 11:59 PM ###
#
# ### Instructions
# This lab is presented as a notebook. Please execute the cells that are already completed and your task is to fill in the code
# between ### BEGIN SOLUTION ### and ### END SOLUTION ###.
#
# #### Important: Please do not add any new cells or change the order of cells. If you have questions, please contact the courseS staff.
#
# In this lab, you will be working with a dataset from NYPD containing data on calls to the New York Police Department. Information about the datasets can be found https://opendata.cityofnewyork.us/

# %% [markdown]
# ## Setup
#
# Note that after activating matplotlib to display figures inline via the IPython magic `%matplotlib inline`, we configure a custom default figure size. Virtually every default aspect of matplotlib [can be customized](https://matplotlib.org/users/customizing.html).

# %%
import pandas as pd
import numpy as np
import zipfile
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 9)

# %% [markdown]
# # Part 1:Getting Data
#
# We will work with the NYPD Historic complaint data set. Our first task is to estimate the size of this download by looking at the number of rows, columns and using an estimated size for a column (use a reasonable value). The site metadata is available from the page
# https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Historic/qgea-i56i

# %%
### BEGIN SOLUTION
# estimated size of the download (based on metadata information from the site) = 1.8 MB      
# please explain how you reached the answer
# Suppose there are 300 chars per row in average = 300 Byte
# Total size = 6.04M * 300 Byte = 1800 MB
### END SOLUTION

# %% [markdown]
# ### 1.1 Download the data
# This file is large (use the estimate you did above). If it takes too long to download, you may want to interrupt and download the file using a browser and URL (https://data.cityofnewyork.us/api/views/5uac-w243/rows.csv?accessType=DOWNLOAD).

# %%
import utils
data_dir = 'data'
data_url = 'https://data.cityofnewyork.us/api/views/qgea-i56i/rows.csv?accessType=DOWNLOAD'

file_name = 'NYPD_Complaint_Data_Historic.csv'

# To retrieve the dataset, we will use the `utils.fetch_and_cache` utility from utils library. 
dest_path = utils.fetch_and_cache(data_url=data_url, file=file_name,data_dir=data_dir)
print(f'Located at {dest_path}')
# Out:
# Using version already downloaded: Sun Feb 10 15:09:16 2019
# MD5 hash of file: 2dc7523c5b42e3dea6b4d980e14d6d4b
# Located at data/NYPD_Complaint_Data_Historic.csv

# %% [markdown]
# ### 1.2 Inspect the size of the file
# It is helpful to get an idea of the size of the file. This can be done using functions in the utils library.

# %%
# look at the size of the file w/o opening it using OS (https://docs.python.org/3/library/os.html). You can perform
# variety of operating system related functions from this package.
### BEGIN SOLUTION
import os
b = os.path.getsize("data/NYPD_Complaint_Data_Historic.csv")
print("File size is", b/1024/1024, "MB.")
#### END SOLUTION
# Out:
# File size is 1810.2397708892822 MB.

# %% [markdown]
# ### 1.3 Split the large file
# This data file NYPD_Complaint_Data_Historic.csv is too big to load into a single DataFrame. Let us split the large file into smaller files.  Let us find out the number of lines in the NYPD_Complaint_Data_Historic.csv file using utils.

# %%
# Using utils library, find the number of lines in the file

### BEGIN SOLUTION
lines = utils.line_count("data/NYPD_Complaint_Data_Historic.csv")
print("Number of lines:", lines)
### END SOLUTION
# Out:
# Number of lines: 6036806

# %%
# Split the file into 10 smaller files. Estimate the number of lines in each file using the count above
# files should be created in the data folder and named NYPD_Complaint_Data_Historic_1.csv, 
# NYPD_Complaint_Data_Historic_2.csv, ... NYPD_Complaint_Data_Historic_10.csv etc
# It is possible that few lines from the original file may not be saved due to rounding errors.

### BEGIN SOLUTION
import os
path, dirs, files = next(os.walk("data"))

if(len(files) > 10):
    print("CSV files created already.")
    for i in np.arange(1, 11):
        file_name = 'data/NYPD_Complaint_Data_Historic{}.csv'.format(i)
        line = utils.line_count(file_name)
        print("File name:", file_name, ", Number of lines:", lines)
else:
    for i,chunk in enumerate(pd.read_csv('data/NYPD_Complaint_Data_Historic.csv', chunksize = int(lines/10+1), low_memory=False)):
        file_name = 'data/NYPD_Complaint_Data_Historic{}.csv'.format(i+1)
        chunk.to_csv(file_name)
        line = utils.line_count(file_name)
        print("File name:", file_name, ", Number of lines:", line)
    
### END SOLUTION
# Out:
# CSV files created already.
# File name: data/NYPD_Complaint_Data_Historic1.csv , Number of lines: 6036806
# File name: data/NYPD_Complaint_Data_Historic2.csv , Number of lines: 6036806
# File name: data/NYPD_Complaint_Data_Historic3.csv , Number of lines: 6036806
# File name: data/NYPD_Complaint_Data_Historic4.csv , Number of lines: 6036806
# File name: data/NYPD_Complaint_Data_Historic5.csv , Number of lines: 6036806
# File name: data/NYPD_Complaint_Data_Historic6.csv , Number of lines: 6036806
# File name: data/NYPD_Complaint_Data_Historic7.csv , Number of lines: 6036806
# File name: data/NYPD_Complaint_Data_Historic8.csv , Number of lines: 6036806
# File name: data/NYPD_Complaint_Data_Historic9.csv , Number of lines: 6036806
# File name: data/NYPD_Complaint_Data_Historic10.csv , Number of lines: 6036806

# %% [markdown]
# ### 1.4 Check the files in the data folder
# Now, we'll use a method of the `Pathlib.Path` class called `glob` to list all files in the `data` directory. You will find useful information in pathlib [docs](https://docs.python.org/3/library/pathlib.html).
#
# Below, we use pathlib's `glob` method to store the list of all files' names from the `data_dir` directory in the variable `file_names`. These names should be strings that contain only the file name (e.g. `dummy.txt` not `data/dummy.txt`). The asterisk (*) character is used with the `glob` method to match any string.

# %%
from pathlib import Path
data_dir_path = Path('data') # creates a Path object that points to the data directory
file_names = [x.name for x in data_dir_path.glob('*') if x.is_file()]
file_names
# Out:
# ['NYPD_Complaint_Data_Historic6.csv',
#  'NYPD_Complaint_Data_Historic7.csv',
#  'NYPD_Complaint_Data_Historic.csv',
#  'NYPD_Complaint_Data_Historic3.csv',
#  'NYPD_Complaint_Data_Historic8.csv',
#  'NYPD_Complaint_Data_Historic1.csv',
#  'NYPD_Complaint_Data_Historic5.csv',
#  'NYPD_Complaint_Data_Historic9.csv',
#  'NYPD_Complaint_Data_Historic4.csv',
#  'NYPD_Complaint_Data_Historic2.csv',
#  'NYPD_Complaint_Data_Historic10.csv']

# %% [markdown]
# ### 1.5 Pre-processing of data
# It is good to pre-process the data to see if the file can be opened in a Jupyter notebook. We need to avoid large files that can crash notebooks. Typically, files of size around 200 MB is ok to open into a DataFrame. In the following activities we will inspect the file w/o opening it as a DataFrame. Using utils.head

# %%
# Use the util.head() to read up to 5 lines from the original file (w/o opening it)
from utils import head
head('data/NYPD_Complaint_Data_Historic.csv')

# Modified utils to print out the head
# head('data/NYPD_Complaint_Data_Historic.csv', 1)
# Out:
# ['CMPLNT_NUM,CMPLNT_FR_DT,CMPLNT_FR_TM,CMPLNT_TO_DT,CMPLNT_TO_TM,ADDR_PCT_CD,RPT_DT,KY_CD,OFNS_DESC,PD_CD,PD_DESC,CRM_ATPT_CPTD_CD,LAW_CAT_CD,BORO_NM,LOC_OF_OCCUR_DESC,PREM_TYP_DESC,JURIS_DESC,JURISDICTION_CODE,PARKS_NM,HADEVELOPT,HOUSING_PSA,X_COORD_CD,Y_COORD_CD,SUSP_AGE_GROUP,SUSP_RACE,SUSP_SEX,TRANSIT_DISTRICT,Latitude,Longitude,Lat_Lon,PATROL_BORO,STATION_NAME,VIC_AGE_GROUP,VIC_RACE,VIC_SEX\n',
#  '590221880,07/09/2007,22:00:00,07/09/2007,22:10:00,109,07/09/2007,344,ASSAULT 3 & RELATED OFFENSES,101,ASSAULT 3,COMPLETED,MISDEMEANOR,QUEENS,INSIDE,RESIDENCE - APT. HOUSE,N.Y. POLICE DEPT,0,NA,,NA,1032818,216783,,,,,40.761570541,-73.82468122,"(40.761570541, -73.82468122)",PATROL BORO QUEENS NORTH,,45-64,WHITE HISPANIC,F\n',
#  '735927640,07/09/2007,22:00:00,,,43,07/09/2007,235,DANGEROUS DRUGS,567,"MARIJUANA, POSSESSION 4 & 5",COMPLETED,MISDEMEANOR,BRONX,FRONT OF,STREET,N.Y. POLICE DEPT,0,NA,,NA,1017076,241640,,,,,40.829868672,-73.881384934,"(40.829868672, -73.881384934)",PATROL BORO BRONX,,,UNKNOWN,E\n',
#  '247194592,07/09/2007,22:00:00,07/09/2007,22:10:00,114,07/09/2007,105,ROBBERY,366,"ROBBERY,BICYCLE",COMPLETED,FELONY,QUEENS,FRONT OF,RESIDENCE - PUBLIC HOUSING,N.Y. HOUSING POLICE,2,NA,QUEENSBRIDGE NORTH,1247,999158,215244,,,,,40.757467209,-73.946190063,"(40.757467209, -73.946190063)",PATROL BORO QUEENS NORTH,,<18,BLACK,M\n',
#  '541237744,07/09/2007,21:50:00,07/09/2007,22:34:00,114,07/09/2007,341,PETIT LARCENY,333,"LARCENY,PETIT FROM STORE-SHOPL",COMPLETED,MISDEMEANOR,QUEENS,INSIDE,CHAIN STORE,N.Y. POLICE DEPT,0,NA,,NA,1008736,213682,,,,,40.753158581,-73.911623363,"(40.753158581, -73.911623363)",PATROL BORO QUEENS NORTH,,,UNKNOWN,D\n']

# %% [markdown]
# ### 1.6 Inspecting and describing data columns
# There should be 35 columns in each record. Using header information and data types, describe the type of data in each
# column. If you are unable to determine, just state so.
# ##### BEGIN SOLUTION
# * CMPLNT_NUM : uint32
# * CMPLNT_FR_DT : datetime64
# * CMPLNT_FR_TM : datetime64
# * CMPLNT_TO_DT : datetime64
# * CMPLNT_TO_TM : datetime64
# * ADDR_PCT_CD : uint8
# * RPT_DT : datetime64
# * KY_CD : uint16
# * OFNS_DESC : category(string)
# * PD_CD : float16
# * PD_DESC : object(string)
# * CRM_ATPT_CPTD_CD : caregory(string)
# * LAW_CAT_CD : caregory(string)
# * BORO_NM : caregory(string)
# * LOC_OF_OCCUR_DESC : caregory(string)
# * PREM_TYP_DESC : caregory(string)
# * JURIS_DESC : caregory(string)
# * JURISDICTION_CODE : category(uint8)
# * PARKS_NM : object(string)
# * HADEVELOPT : object(string)
# * HOUSING_PSA : float32
# * X_COORD_CD : float32
# * Y_COORD_CD : float32
# * SUSP_AGE_GROUP : category(string)
# * SUSP_RACE : category(string)
# * SUSP_SEX : category(char)
# * TRANSIT_DISTRICT :
# * Latitude : float32
# * Longitude : float32
# * Lat_Lon : object(string)
# * PATROL_BORO : object(string)
# * STATION_NAME : object(string)
# * VIC_AGE_GROUP : object(string)
# * VIC_RACE : object(string)
# * VIC_SEX : category(char)
# ##### END SOLUTION

# %% [markdown]
# # Part 2 - Exploratory Data Analysis
# Exploratory data analysis (EDA) is the process of examining a subest of a large data set to see what we can know about the data. First we will explore one file NYPD_Complaint_Data_Historic_1.csv to see what we can find out.
#
# ### 2.1 Loading Data into a DataFrame
# Load the first CSV file, NYPD_Complaint_Data_Historic_1.csv into a `pandas.DataFrame` object. Also do a time analysis to see how long it took to load the data into a DataFrame. Time should be printed in seconds. The time libraries https://docs.python.org/3/library/time.html can help.

# %%
### BEGIN SOLUTION

from time import time

t = time()
calls = pd.read_csv('data/NYPD_Complaint_Data_Historic1.csv')
print("Time spent:", time()-t, "seconds.")

### END SOLUTION
# Out:
# Time spent: 3.258950710296631 seconds.

# %% [markdown]
# ### 2.2 Description of Fields
# Let's also check some basic information about these files using the `DataFrame.describe` and `DataFrame.info` methods. Describe columns that can be removed based on the information.

# %%
### BEGIN SOLUTION
calls.info()
calls.describe()

# What columns can be removed from the DataFrame? A reasonable rule of thumb is that if a column is missing more than 
# 50% of the data then it should be removed

# columns that can be removed: PARKS_NM, HADEVELOPT, HOUSING_PSA, SUSP_AGE_GROUP, TRANSIT_DISTRICT, STATION_NAME
# columns that can be removed or kept: SUSP_RACE, SUSP_SEX 


### END SOLUTION
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603681 entries, 0 to 603680
# Data columns (total 36 columns):
# Unnamed: 0           603681 non-null int64
# CMPLNT_NUM           603681 non-null int64
# CMPLNT_FR_DT         603590 non-null object
# CMPLNT_FR_TM         603664 non-null object
# CMPLNT_TO_DT         411325 non-null object
# CMPLNT_TO_TM         412057 non-null object
# ADDR_PCT_CD          603164 non-null float64
# RPT_DT               603681 non-null object
# KY_CD                603681 non-null int64
# OFNS_DESC            601388 non-null object
# PD_CD                603098 non-null float64
# PD_DESC              603098 non-null object
# CRM_ATPT_CPTD_CD     603681 non-null object
# LAW_CAT_CD           603681 non-null object
# BORO_NM              601569 non-null object
# LOC_OF_OCCUR_DESC    466892 non-null object
# PREM_TYP_DESC        597584 non-null object
# JURIS_DESC           603681 non-null object
# JURISDICTION_CODE    603098 non-null float64
# PARKS_NM             0 non-null float64
# HADEVELOPT           29103 non-null object
# HOUSING_PSA          45202 non-null float64
# X_COORD_CD           603492 non-null float64
# Y_COORD_CD           603492 non-null float64
# SUSP_AGE_GROUP       79381 non-null object
# SUSP_RACE            244637 non-null object
# SUSP_SEX             195141 non-null object
# TRANSIT_DISTRICT     12473 non-null float64
# Latitude             603492 non-null float64
# Longitude            603492 non-null float64
# Lat_Lon              603492 non-null object
# PATROL_BORO          603098 non-null object
# STATION_NAME         12473 non-null object
# VIC_AGE_GROUP        402136 non-null object
# VIC_RACE             603681 non-null object
# VIC_SEX              603681 non-null object
# dtypes: float64(10), int64(3), object(23)
# memory usage: 165.8+ MB
#           Unnamed: 0    CMPLNT_NUM    ADDR_PCT_CD          KY_CD  \
# count  603681.000000  6.036810e+05  603164.000000  603681.000000
# mean   301840.000000  5.503952e+08      63.207914     292.469047
# std    174267.838265  2.596528e+08      34.656600     148.734542
# min         0.000000  1.000018e+08       1.000000     101.000000
# 25%    150920.000000  3.259219e+08      40.000000     114.000000
# 50%    301840.000000  5.504028e+08      63.000000     341.000000
# 75%    452760.000000  7.750000e+08      94.000000     351.000000
# max    603680.000000  9.999991e+08     123.000000     881.000000
#
#                PD_CD  JURISDICTION_CODE  PARKS_NM   HOUSING_PSA    X_COORD_CD  \
# count  603098.000000      603098.000000       0.0  45202.000000  6.034920e+05
# mean      421.476316           0.726610       NaN   5152.608469  1.004456e+06
# std       215.714929           6.675142       NaN  11774.325487  2.187908e+04
# min       101.000000           0.000000       NaN     28.000000  1.110000e+02
# 25%       254.000000           0.000000       NaN    485.000000  9.913420e+05
# 50%       397.000000           0.000000       NaN    696.000000  1.003989e+06
# 75%       637.000000           0.000000       NaN    936.000000  1.016487e+06
# max       969.000000          97.000000       NaN  61882.000000  1.067249e+06
#
#           Y_COORD_CD  TRANSIT_DISTRICT       Latitude      Longitude
# count  603492.000000      12473.000000  603492.000000  603492.000000
# mean   206861.426945         13.511665      40.734421     -73.927056
# std     30687.932864         12.587050       0.084235       0.078900
# min       111.000000          1.000000      40.112710     -77.519206
# 25%    184180.500000          3.000000      40.672144     -73.974418
# 50%    206096.000000          4.000000      40.732299     -73.928748
# 75%    235225.000000         30.000000      40.812297     -73.883613
# max    271820.000000         34.000000      40.912723     -73.700493

# %% [markdown]
# ### 2.2 Finding Uniques
#
# Notice that the functions above reveal type information for the columns, as well as some basic statistics about the numerical columns found in the DataFrame. However, we still need more information about what each column represents. Let's explore the data further.
#
# find the number of unique values in each DataFrame column and answer the questions below.

# %%
### BEGIN SOLUTION
calls.nunique()

# Questions
# 1. How many distinct locations where the complaints have come from?
#     79300

# 2. How many age groups are represented in the data set?
#     13

# 3. How many boroughs are included in the data set?
#     12

# 4. How many offense types are listed in this data set?
#     61

### END SOLUTION
# Out:
# Unnamed: 0           603681
# CMPLNT_NUM           603681
# CMPLNT_FR_DT           2218
# CMPLNT_FR_TM           1441
# CMPLNT_TO_DT           1353
# CMPLNT_TO_TM           1441
# ADDR_PCT_CD              76
# RPT_DT                  419
# KY_CD                    73
# OFNS_DESC                64
# PD_CD                   343
# PD_DESC                 333
# CRM_ATPT_CPTD_CD          2
# LAW_CAT_CD                3
# BORO_NM                   5
# LOC_OF_OCCUR_DESC         5
# PREM_TYP_DESC            70
# JURIS_DESC               19
# JURISDICTION_CODE        19
# PARKS_NM                  0
# HADEVELOPT              261
# HOUSING_PSA            1653
# X_COORD_CD            53626
# Y_COORD_CD            56840
# SUSP_AGE_GROUP           24
# SUSP_RACE                 7
# SUSP_SEX                  3
# TRANSIT_DISTRICT         12
# Latitude              79178
# Longitude             79178
# Lat_Lon               79186
# PATROL_BORO               8
# STATION_NAME            362
# VIC_AGE_GROUP            62
# VIC_RACE                  7
# VIC_SEX                   5
# dtype: int64

# %% [markdown]
# ### 2.3 Offense by Boro
# Using GroupBy operation, create a DataFrame that groups offenses by Boro. call the DataFrame calls_by_Boro_and_offense

# %%
### BEGIN SOLUTION
calls_by_Boro_and_offense = calls.groupby(['BORO_NM', 'OFNS_DESC']).size()
# calls_by_Boro_and_offense["BRONX", "GRAND LARCENY"]
### END SOLUTION

# %%
calls_by_Boro_and_offense
# Out:
# BORO_NM        OFNS_DESC
# BRONX          ADMINISTRATIVE CODE                 255
#                ALCOHOLIC BEVERAGE CONTROL LAW       40
#                ANTICIPATORY OFFENSES                 4
#                ARSON                               507
#                ASSAULT 3 & RELATED OFFENSES      13574
#                BURGLAR'S TOOLS                      14
#                BURGLARY                           4166
#                CHILD ABANDONMENT/NON SUPPORT        19
#                CRIMINAL MISCHIEF & RELATED OF    12477
#                CRIMINAL TRESPASS                  3633
#                DANGEROUS DRUGS                   17397
#                DANGEROUS WEAPONS                  4236
#                DISORDERLY CONDUCT                   13
#                DISRUPTION OF A RELIGIOUS SERV        1
#                ESCAPE 3                             14
#                FELONY ASSAULT                     4878
#                FORGERY                             934
#                FRAUDS                              504
#                FRAUDULENT ACCOSTING                 23
#                GAMBLING                             65
#                GRAND LARCENY                      6026
#                GRAND LARCENY OF MOTOR VEHICLE     3395
#                HARRASSMENT 2                     15491
#                HOMICIDE-NEGLIGENT,UNCLASSIFIE        2
#                HOMICIDE-NEGLIGENT-VEHICLE            1
#                INTOXICATED & IMPAIRED DRIVING     1490
#                KIDNAPPING & RELATED OFFENSES       100
#                LOITERING                             1
#                LOITERING FOR DRUG PURPOSES           2
#                LOITERING/DEVIATE SEX                 1
#                                                  ...
# STATEN ISLAND  FRAUDS                              309
#                FRAUDULENT ACCOSTING                  2
#                GAMBLING                              1
#                GRAND LARCENY                      1307
#                GRAND LARCENY OF MOTOR VEHICLE      552
#                HARRASSMENT 2                      5680
#                INTOXICATED & IMPAIRED DRIVING      622
#                KIDNAPPING & RELATED OFFENSES        14
#                MISCELLANEOUS PENAL LAW             453
#                NEW YORK CITY HEALTH CODE             1
#                NYS LAWS-UNCLASSIFIED FELONY         20
#                OFF. AGNST PUB ORD SENSBLTY &      2539
#                OFFENSES AGAINST PUBLIC ADMINI      798
#                OFFENSES AGAINST PUBLIC SAFETY        9
#                OFFENSES AGAINST THE PERSON          51
#                OFFENSES INVOLVING FRAUD             29
#                OFFENSES RELATED TO CHILDREN         13
#                OTHER OFFENSES RELATED TO THEF       39
#                OTHER STATE LAWS                      2
#                OTHER STATE LAWS (NON PENAL LA        6
#                PETIT LARCENY                      4460
#                PETIT LARCENY OF MOTOR VEHICLE        5
#                POSSESSION OF STOLEN PROPERTY        88
#                RAPE                                 60
#                ROBBERY                             496
#                SEX CRIMES                          202
#                THEFT-FRAUD                         413
#                UNAUTHORIZED USE OF A VEHICLE       124
#                UNLAWFUL POSS. WEAP. ON SCHOOL        1
#                VEHICLE AND TRAFFIC LAWS            180
# Length: 269, dtype: int64

# %%
## Assert that in Bronx there were 6022 Grand Larceny incidents
### BEGIN SOLUTION
# assert calls_by_Boro_and_offense["BRONX", "GRAND LARCENY"] == 6022

assert calls_by_Boro_and_offense["BRONX", "GRAND LARCENY"] == 6026
# everyone will have different answers depended on how they split the file in the first place

### END SOLUTION

# %% [markdown]
# ### 2.4 Offenses in Bronx
#
# In the cell below, find a list of strings corresponding to the possible values for `OFNS_DESC` when `BORO` is "BRONX". Create an expression that automatically extracts the names of the offenses.

# %%
### BEGIN SOLUTION
x = calls_by_Boro_and_offense["BRONX"].keys().values.tolist()
print(x)
### END SOLUTION


# How many offenses were committed in Bronx during the analysis period?
#     53 different kinds of offenses, with the total of 129463 offenses
print("\n", len(x), "different kinds", "with total of", calls_by_Boro_and_offense["BRONX"].sum())
# Out:
# ['ADMINISTRATIVE CODE', 'ALCOHOLIC BEVERAGE CONTROL LAW', 'ANTICIPATORY OFFENSES', 'ARSON', 'ASSAULT 3 & RELATED OFFENSES', "BURGLAR'S TOOLS", 'BURGLARY', 'CHILD ABANDONMENT/NON SUPPORT', 'CRIMINAL MISCHIEF & RELATED OF', 'CRIMINAL TRESPASS', 'DANGEROUS DRUGS', 'DANGEROUS WEAPONS', 'DISORDERLY CONDUCT', 'DISRUPTION OF A RELIGIOUS SERV', 'ESCAPE 3', 'FELONY ASSAULT', 'FORGERY', 'FRAUDS', 'FRAUDULENT ACCOSTING', 'GAMBLING', 'GRAND LARCENY', 'GRAND LARCENY OF MOTOR VEHICLE', 'HARRASSMENT 2', 'HOMICIDE-NEGLIGENT,UNCLASSIFIE', 'HOMICIDE-NEGLIGENT-VEHICLE', 'INTOXICATED & IMPAIRED DRIVING', 'KIDNAPPING & RELATED OFFENSES', 'LOITERING', 'LOITERING FOR DRUG PURPOSES', 'LOITERING/DEVIATE SEX', 'MISCELLANEOUS PENAL LAW', 'NEW YORK CITY HEALTH CODE', 'NYS LAWS-UNCLASSIFIED FELONY', 'OFF. AGNST PUB ORD SENSBLTY &', 'OFFENSES AGAINST PUBLIC ADMINI', 'OFFENSES AGAINST PUBLIC SAFETY', 'OFFENSES AGAINST THE PERSON', 'OFFENSES INVOLVING FRAUD', 'OFFENSES RELATED TO CHILDREN', 'OTHER OFFENSES RELATED TO THEF', 'OTHER STATE LAWS', 'OTHER STATE LAWS (NON PENAL LA', 'PETIT LARCENY', 'PETIT LARCENY OF MOTOR VEHICLE', 'POSSESSION OF STOLEN PROPERTY', 'PROSTITUTION & RELATED OFFENSES', 'RAPE', 'ROBBERY', 'SEX CRIMES', 'THEFT OF SERVICES', 'THEFT-FRAUD', 'UNAUTHORIZED USE OF A VEHICLE', 'VEHICLE AND TRAFFIC LAWS']
#
#  53 different kinds with total of 129463

# %% [markdown]
# ### 2.5 Most Common Crimes in NYC
#
# What are the five crime types of OFNS_DESC that have the most crime events in Bronx? You may need to use `value_counts` to find the answer. Save your results as a list of strings.
#
# **Hint:** *The `keys` method of the Series class might be useful.*

# %%
### BEGIN SOLUTION
calls_by_Boro_and_offense["BRONX"].nlargest(5).keys().to_list()
### END SOLUTION
# Out:
# ['DANGEROUS DRUGS',
#  'HARRASSMENT 2',
#  'PETIT LARCENY',
#  'ASSAULT 3 & RELATED OFFENSES',
#  'CRIMINAL MISCHIEF & RELATED OF']

# %% [markdown]
# ### 2.6 Probability of a Crime in Bronx
# What is the probability that a the crime "Arson" can happen in Bronx?

# %%
### BEGIN SOLUTION
calls_by_Boro_and_offense["BRONX", "ARSON"]/calls_by_Boro_and_offense["BRONX"].sum()
### END SOLUTION
# Out:
# 0.00391617682272155

# %% [markdown]
# ---
# # Part 3: Visualizing the Data
#
# ## Pandas vs. Seaborn Plotting
#
# Pandas offers basic functionality for plotting. For example, the `DataFrame` and `Series` classes both have a `plot` method. However, the basic plots generated by pandas are not particularly pretty. While it's possible to manually use matplotlib commands to make pandas plots look better, we'll instead use a high level plotting library called Seaborn that will take care of most of this for us.
#
# As you learn to do data visualization, you may find the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html) and [Seaborn documentation](https://seaborn.pydata.org/api.html) helpful!

# %% [markdown]
# ### 3.1 Plotting a Series
# Using the built-in plotting functionality of pandas, such as `plot` method of the `Series` class to generate a `barh` plot type,  display the value counts for `OFNS_DESC` visually as a barh chart.

# %%
### BEGIN SOLUTION
list = calls.groupby(['OFNS_DESC']).size().sort_values()
# print(list)
df = list.plot(kind = "barh", figsize = (8,16), color = '#ff6f69')
### END SOLUTION

# %% [markdown]
# ### 3.2 Getting a Better Plot
# The plot above can be messy as it plots all offenses. Plot only the offenses that has more than 10000 calls

# %%
### BEGIN SOLUTION
s = list[list > 10000]
df = s.plot(kind = "barh", figsize = (8,8), color='#96ceb4')

### END SOLUTION

# %% [markdown]
# By contrast, the Seaborn library provides a specific function `countplot` built for plotting counts. It operates directly on the DataFrame itself i.e. there's no need to call `value_counts()` at all. This higher level approach makes it easier to work with. Use the y-label ("Crime Category"), x-label("Number of Calls") and title_of_plot("Number of Calls By Crime Type"

# %%
### BEGIN SOLUTION

import seaborn as sns
from matplotlib.pyplot import figure, show
list1 = s.to_frame()
list1.columns = ["COUNT"]

figure(figsize=(8,16))
ax = sns.countplot(data= calls, y = 'OFNS_DESC')
ax.set_xlabel("Number of Calls")
ax.set_ylabel("Crime Category")
ax.set_title("Number of Calls By Crime Type")
show()
### END SOLUTION

# %% [markdown]
# You may note that the ordering might be different for the seaborn plot (as compared to pandas plot). If we want the same ordering that we had in the pandas plot, we can use the order parameter of the `countplot` method. It takes a list of strings corresponding to the axis to be ordered. By passing the index of the `value_counts`, you can get the order you want.

# %%
### BEGIN SOLUTION
figure(figsize=(8,16))
p = sns.countplot(data= calls, y = 'OFNS_DESC', order = calls['OFNS_DESC'].value_counts().index)

p.set_xlabel("Number of Calls")
p.set_ylabel("Crime Category")
p.set_title("Number of Calls By Crime Type")
show()
### END SOLUTION

# %% [markdown]
# Now we have a pretty bar plot with the bars ordered by size. Though `seaborn` appears to provide a superior plot from a aesthetic point of view, the `pandas` plotting library is also good to understand. You'll get practice using both libraries in the following questions.
#
# ## An Additional Note on Plotting in Jupyter Notebooks
#
# You may have noticed that many of our code cells involving plotting end with a semicolon (;). This prevents any extra output from the last line of the cell that we may not want to see. Try adding this to your own code in the following questions!

# %% [markdown]
# ### 3.3 making more plots
#
# Now it is your turn to make some more plots using `pandas` and `seaborn`. Let's start by looking at the distribution of calls over days of the week.
#
# The CMPLNT_FR_DT field contains the date of the event. We would like to add a new column to the DataFrame that includes Day of the week (DAY_OF_WEEK) that indicates the day of the week. This can help us analyze the crimes on a specific day of the week. For example, we can answer questions such as "what day of the week that a LARSON is likely to happen in NYC?"
#
#
# Add a new column `DAY_OF_WEEK` into the `calls` dataframe that has the day string (eg. 'Sunday') for the corresponding value in CMPLNT_FR_DT. For example, if the first 3 values of `CMPLNT_FR_DT` are `['01/27/2006, '01/28/2006, '01/29/2006]`, then the first 3 values of the `DAY_OF_WEEK` column should be `["Friday", "Saturday", "Sunday"]`.
#
# **Hint:** *Try using the [Series.map](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.map.html) function on `calls["OFNS_DESC"]`.  Can you assign this to the new column `calls["DAY_OF_WEEK"]`?*

# %%
days = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
### BEGIN SOLUTION
calls['CMPLNT_FR_DT'] = pd.to_datetime(calls['CMPLNT_FR_DT'])
calls['DAY_OF_WEEK'] = calls['CMPLNT_FR_DT'].dt.weekday_name

### END SOLUTION

# %% [markdown]
# ### 3.4 Seaborn plots
#
# Create a `seaborn` plot that shows the number of calls for each day of the week. You may want to use of the `rotation` argument in `ax.set_xticklabels`, which rotates the labels by 90 degrees.

# %%
### BEGIN SOLUTION

figure(figsize=(8,6))
calls['DAY_OF_WEEK'] = pd.Categorical(calls['DAY_OF_WEEK'], days)
calls.sort_values("DAY_OF_WEEK")
p = sns.countplot(data= calls, x = 'DAY_OF_WEEK')

p.set_xlabel("Day of week")
p.set_ylabel("Count")
p.set_title("Number of Calls By day of week")
show()

### END SOLUTION

# %% [markdown]
# Now, let's make the same plot using `pandas`. Construct a vertical bar plot with the count of the number of calls (entries in the table) for each day of the week **ordered by the day of the week** (eg. `Sunday`, `Monday`, ...). Do not use `sns` for this plot. Be sure that your axes are labeled and that your plot is titled.
#
# **Hint:** *Given a series `s`, and an array `coolIndex` that has the same entries as in `s.index`, `s[coolIndex]` will return a copy of the series in the same order as `coolIndex`.*

# %%
### BEGIN SOLUTION
figure(figsize=(8,8))
s1 = calls.groupby("DAY_OF_WEEK").size().reindex(days) 
ax = s1.plot(kind = "bar", color = '#ff6f69')
ax.set_xticklabels(s1.index, rotation=True)
ax.set_xlabel("Day of week")
ax.set_ylabel("Count")
ax.set_title("Number of Calls By day of week")
show()
### END SOLUTION

# %% [markdown]
# ## 3.5 What Day of the Week is more calls?
#
# Is it true that weekdays generally have slightly more calls than Saturday or Sunday? What can you say about the difference?
#
# ##### BEGIN SOLUTION
#
# Friday has the most calls.
#
# Based on the graph, it seems true that weekdays generally have a slightly more calls than Saturday or Sunday. It may be because many people choose to take a break on the weekend while having to work on the weekdays.
#
# ##### END SOLUTION
#
# We can break down into some particular types of events to see their distribution. For example, let's make a bar plot for the OFNS_DESC "HARRASSMENT 2". Which day is the peak for "HARRASSMENT 2"?
#
# This time, use `seaborn` to create a vertical bar plot of the number of total noise violations reported on each day of the week, again ordered by the days of the week starting with Sunday. Do not use `pandas` to plot.
#
# **Hint:** *If you're stuck, use the code for the seaborn plot in above question as a starting point.*

# %%
### BEGIN SOLUTION

l2 = calls.loc[calls['OFNS_DESC'] == "HARRASSMENT 2"]
l2.reindex(days)
figure(figsize=(8,6))
p = sns.countplot(data= l2, x = 'DAY_OF_WEEK')

p.set_xlabel("Day of week")
p.set_ylabel("Count")
p.set_title("Number of Calls By day of week")
show()
### END SOLUTION

# %% [raw]
# ### 3.6
#
# Do you see anything interesting about the distribution of HARRASSMENT 2 calls over a week? Type a short answer below.
# ##### BEGIN SOLUTION
#
# Weekdays generally have a slightly more calls than Saturday or Sunday. It may be because many people choose to take a break on the weekend while having to work on the weekdays. And it is reasonable because the weekdays have more crime callss in general.
#
# ##### END SOLUTION

# %% [markdown]
# ### 3.7 More Plots
#
# Let's look at a similar distribution but for a crime we have much more calls data about. In the cell below, create the same plot as you did in previous questions, but now looking at instances of the OFNS_DESC "BURGLARY" (instead of "HARRASSMENT 2"). Use either `pandas` or `seaborn` plotting as you desire.

# %%
### BEGIN SOLUTION

l2 = calls.loc[calls['OFNS_DESC'] == "BURGLARY"]
figure(figsize=(8,6))
p = sns.countplot(data= l2, x = 'DAY_OF_WEEK')

p.set_xlabel("Day of week")
p.set_ylabel("Count")
p.set_title("Number of Calls By day of week")
show()
### END SOLUTION

# %% [markdown]
# ### 3.8 time of events
#
# Now let's look at the CMPLNT_TO_TM column which indicates the time for events. Since it contains hour and minute information, let's extract the hour info and create a new column named `Hour` in the `calls` dataframe. You should save the hour as an `int`. Then plot the frequency of each hour in the table (i.e., `value_counts()`) sorted by the hour of the day (i.e., `sort_index()`).
#
# You will want to look into how to use:
#
# * [Series.str.slice](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.str.slice.html#pandas.Series.str.slice) to select the substring.
# * [Series.astype](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.astype.html) to change the type.
#
# **Hint:** *The `str` helper member of a series can be used to grab substrings.  For example, `calls["CMPLNT_TO_TM"].str.slice(3,5)` returns the minute of each hour of the `CMPLNT_TO_TM`.*

# %%
### BEGIN SOLUTION
calls['Hour'] = calls["CMPLNT_TO_TM"].str.slice(0,2).fillna(-1).astype('int8')
l3 = calls.groupby(['Hour']).size().sort_index()
s3 = l3[l3.index > -1]
df = s3.plot(kind = "barh", figsize = (8,8), color='#96ceb4')

### END SOLUTION

# %% [markdown]
# Create a pandas bar plot showing the number of BURGLARY crimes committed at each hour of the day. Use the labels
# * ax.set_xlabel("Hour of the Day")
# * ax.set_ylabel("Number of Calls")
# * ax.set_title("Number of Calls Reporting Fraud For Each Day of the Week");

# %%
### BEGIN SOLUTION

l2 = calls.loc[calls['OFNS_DESC'] == "BURGLARY"]
s1 = l2.groupby("Hour").size().reindex(np.arange(25)) 

figure(figsize=(8,8))

ax = s1.plot(kind = "bar", color = '#ff6f69')
ax.set_xticklabels(s1.index, rotation=True)
ax.set_xlabel("Hour")
ax.set_ylabel("Count")
ax.set_title("Number of Calls By Hours")
show()

### END SOLUTION

# %% [markdown]
# ### 3.9 More plots
#
# In the cell below, create a seaborn plot of the same data. Again, make sure you provide axes labels and a title for your plot.

# %%
### BEGIN SOLUTION

l2 = calls.loc[(calls['OFNS_DESC'] == "BURGLARY") & (calls['Hour'] > -1)]
figure(figsize=(8,6))
p = sns.countplot(data= l2, x = 'Hour')

p.set_xlabel("Day of week")
p.set_ylabel("Count")
p.set_title("Number of Calls By day of week")
show()

### END SOLUTION

# %% [markdown]
# ### 3.8 Spike in burglary?
#
# According to your plots, is there a spike in calls reporting BURGLARY at midnight? If so, Do you trust that this spike is legitimate, or could there be an issue with our data? Explain your reasoning in 1-2 sentences below.
#
# #### BEGIN SOLUTION
#
# No, there is not a spike in calls reporting at midnight.
#
# Burglary often happends when people are in deep sleep or when they are off to work. I believe that the second case hepends more often. If so, the second peak on the plot should be a  bigger peak then.
#
#
# #### END SOLUTION

# %% [markdown]
# In the cell below, we generate a boxplot which examines the hour of day of each crime broken down by the `OFNS_DESC` value.  To construct this plot we used the [DataFrame.boxplot](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.boxplot.html) documentation.

# %%
calls.boxplot(column="Hour", by='OFNS_DESC', rot=90);

# %% [markdown]
# While the pandas boxplot is informative, we can use seaborn to create a more visually-appealing plot. Using seaborn, regenerate a better box plot. See either the textbook (https://www.textbook.ds100.org/ch/06/viz_quantitative.html) or the [seaborn boxplot documentation](https://seaborn.pydata.org/generated/seaborn.boxplot.html).
#
# Looking at your plot, which crime type appears to have the largest interquartile range? Put your results into `answer` as a string.

# %%
# Todo: Make a boxplot with seaborn
### BEGIN SOLUTION
figure(figsize=(16,25))
ax = sns.boxplot(x="Hour", y='OFNS_DESC', data = calls);
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax.set_title("Distributions of Calls Over Hours in a Day, Grouped by Crime");
show()
answer = "OTHER TRAFFIC INFRACTION"
### END SOLUTION

# %% [markdown]
# ### 3.9 - Visualization of crimes on a Map of NYC
# finally we attempt to visualize the crimes committed in NYC on a Map. First we need to installing some mapping software. run the cell below to install folium package for mapping software.

# %%
# !pip install --upgrade folium

# %%
### Plot the maps for BURGLARY in NYC
### if it takes too much time or map does not show up, try plotting a subset of the data set of for a specific crime

### BEGIN SOLUTION
import folium
l2 = calls.loc[(calls['OFNS_DESC'] == "BURGLARY") & (calls['Latitude'] != np.nan) & (calls['Longitude'] != np.nan)]
locations = l2[['Latitude', 'Longitude']]
locationlist = locations.values.tolist()
# len(locationlist)
# locationlist[7]
map = folium.Map(location=[40.62, -73.92], zoom_start=12)
for point in range(0, 200):
    folium.Marker(locationlist[point]).add_to(map)
map

### END SOLUTION
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Congratulations !!!
#
# <div class="alert alert-block alert-info">
# <h2>Submission Instructions</h2>
# <b> File Name:</b> Please name the file as your_section_your_netID_Lab3.jpynb<br>
# <b> Submit To: </b> Canvas &rarr; Assignments &rarr; Lab3 <br>
# <b>Warning:</b> Failure to follow directions may result in loss of points.<br>
# </div>

# %% [markdown]
# Credits: Josh Hug, and Berkeley Data Science Group for their contributions to the original version.
